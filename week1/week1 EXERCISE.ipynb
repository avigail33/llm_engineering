# %% [markdown]
# # End of week 1 exercise
#
# To demonstrate your familiarity with OpenAI API, and also Ollama, build a tool that takes a technical question,
# and responds with an explanation. This is a tool that you will be able to use yourself during the course!

# %%
# imports
import os
import json
from IPython.display import Markdown, display, update_display
from openai import OpenAI

# %%
# constants

MODEL_GPT = 'gpt-4o-mini'
MODEL_LLAMA = 'llama3.2'

# %%
# set up environment
OLLAMA_BASE_URL = "http://localhost:11434/v1"
ollama = OpenAI(base_url=OLLAMA_BASE_URL, api_key='ollama')

# %%
# here is the question; type over this to ask something new

question = """
Please explain what this code does and why:
yield from {book.get("author") for book in books if book.get("author")}
"""

# %%
# Get gpt-4o-mini to answer, with streaming

# %%
system_prompt =  """
You get asked a technical question, and needs to respond with detailed information.
"""
def get_answer(question):
    response = ollama.chat.completions.create(
        model=MODEL_LLAMA,
        messages=[
            {"role": "system", "content": system_prompt},
            {"role": "user", "content": question}
        ]
    ) # Get Llama 3.2 to answer
    result = response.choices[0].message.content
    display(Markdown(result))
get_answer(question)
# Out:
# **Breaking Down the Code**
#
# The given code is using Python's `yield` keyword to generate a sequence of authors from a collection of books.
#
# Here's the breakdown:
#
# - `{book.get("author") for book in books if book.get("author")}`: This part uses a **list comprehension**. It iterates over each item (`book`) in the collection of books (`books`). For each `book`, it tries to get its value under the key `"author"`. The resulting sequence is generated based on whether this operation is successful (i.e., `book.get("author")` doesn't return `None`).
#
# - `yield from`: This keyword is used with a generator expression or the `yield from` keyword by itself to produce a new iterable, where each item yields will be yielded from.
#
# - Without the `from`, this would create a single generator and its inner iteration over `books` and successful author retrieval.
#
# **What it Does:**
#
# In summary, this code generates an iterator over a sequence of authors from a collection of books (`books`). It skips any book that does not have an `"author"` key defined.
#
# Here's some actual output from a simple example:
#
# ```python
# books = [
#     {"title": "Book1", "author": "AuthorA"},
#     {"title": "Book2", "author": None},
#     {"title": "Book3"}
# ]
#
# for author in yield from {book.get("author") for book in books if book.get("author")}:
#     print(author)
# ```
# Output:
#
# ```
# AuthorA
# ```
#
# And without the `from` (as a list comprehension):
#
# ```python
# books = [
#     {"title": "Book1", "author": "AuthorA"},
#     {"title": "Book2", "author": None},
#     {"title": "Book3"}
# ]
#
# [author for book in books if book.get("author")]  # This skips the author because it's not found.
# ```
# Output:
#
# `['AuthorA']`
#
# In both cases, only one item is printed, as the `yield from` allows us to efficiently use `for` inside another iterable function without repeating operations.
