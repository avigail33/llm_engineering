# %% [markdown]
# # Welcome to Week 2!
#
# ## Frontier Model APIs
#
# In Week 1, we used multiple Frontier LLMs through their Chat UI, and we connected with the OpenAI's API.
#
# Today we'll connect with them through their APIs..

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Important Note - Please read me</h2>
#             <span style="color:#900;">I'm continually improving these labs, adding more examples and exercises.
#             At the start of each week, it's worth checking you have the latest code.<br/>
#             First do a git pull and merge your changes as needed</a>. Check out the GitHub guide for instructions. Any problems? Try asking ChatGPT to clarify how to merge - or contact me!<br/>
#             </span>
#         </td>
#     </tr>
# </table>
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/resources.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#f71;">Reminder about the resources page</h2>
#             <span style="color:#f71;">Here's a link to resources for the course. This includes links to all the slides.<br/>
#             <a href="https://edwarddonner.com/2024/11/13/llm-engineering-resources/">https://edwarddonner.com/2024/11/13/llm-engineering-resources/</a><br/>
#             Please keep this bookmarked, and I'll continue to add more useful links there over time.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# ## Setting up your keys - OPTIONAL!
#
# We're now going to try asking a bunch of models some questions!
#
# This is totally optional. If you have keys to Anthropic, Gemini or others, then you can add them in.
#
# If you'd rather not spend the extra, then just watch me do it!
#
# For OpenAI, visit https://openai.com/api/
# For Anthropic, visit https://console.anthropic.com/
# For Google, visit https://aistudio.google.com/
# For DeepSeek, visit https://platform.deepseek.com/
# For Groq, visit https://console.groq.com/
# For Grok, visit https://console.x.ai/
#
#
# You can also use OpenRouter as your one-stop-shop for many of these! OpenRouter is "the unified interface for LLMs":
#
# For OpenRouter, visit https://openrouter.ai/
#
#
# With each of the above, you typically have to navigate to:
# 1. Their billing page to add the minimum top-up (except Gemini, Groq, Google, OpenRouter may have free tiers)
# 2. Their API key page to collect your API key
#
# ### Adding API keys to your .env file
#
# When you get your API keys, you need to set them as environment variables by adding them to your `.env` file.
#
# ```
# OPENAI_API_KEY=xxxx
# ANTHROPIC_API_KEY=xxxx
# GOOGLE_API_KEY=xxxx
# DEEPSEEK_API_KEY=xxxx
# GROQ_API_KEY=xxxx
# GROK_API_KEY=xxxx
# OPENROUTER_API_KEY=xxxx
# ```
#
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Any time you change your .env file</h2>
#             <span style="color:#900;">Remember to Save it! And also rerun load_dotenv(override=True)<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# imports

import os
import requests
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import Markdown, display

# %%
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')
grok_api_key = os.getenv('GROK_API_KEY')
openrouter_api_key = os.getenv('OPENROUTER_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")

if grok_api_key:
    print(f"Grok API Key exists and begins {grok_api_key[:4]}")
else:
    print("Grok API Key not set (and this is optional)")

if openrouter_api_key:
    print(f"OpenRouter API Key exists and begins {openrouter_api_key[:3]}")
else:
    print("OpenRouter API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins xxxx
# Anthropic API Key exists and begins xxxx
# Google API Key exists and begins AI
# DeepSeek API Key exists and begins xxx
# Groq API Key exists and begins gsk_
# Grok API Key exists and begins xxxx
# OpenRouter API Key exists and begins sk-

# %%
# Connect to OpenAI client library
# A thin wrapper around calls to HTTP endpoints

openai = OpenAI()

# For Gemini, DeepSeek and Groq, we can use the OpenAI python client
# Because Google and DeepSeek have endpoints compatible with OpenAI
# And OpenAI allows you to change the base_url

anthropic_url = "https://api.anthropic.com/v1/"
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
deepseek_url = "https://api.deepseek.com"
groq_url = "https://api.groq.com/openai/v1"
grok_url = "https://api.x.ai/v1"
openrouter_url = "https://openrouter.ai/api/v1"
ollama_url = "http://localhost:11434/v1"

anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)

# %%
tell_a_joke = [
    {"role": "user", "content": "Tell a joke for a student on the journey to becoming an expert in LLM Engineering"},
]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Why did the LLM engineering student spend three days meticulously crafting a complex, multi-turn prompt, complete with few-shot examples, chain-of-thought reasoning, and specific JSON output requirements, all designed to extract critical insights from a massive dataset?
#
# They hit 'generate' with anticipation.
#
# The LLM confidently responded:
# "As an AI, I am unable to access real-time information or express personal opinions. However, I can offer a charming haiku about a squirrel chasing an acorn, followed by a step-by-step guide on how to bake the perfect gluten-free croissant. Would you like me to elaborate on the history of interpretive dance?"
#
# The student just stared at the screen and muttered, "I just wanted the sales figures for Q3..."

# %%
response = groq.chat.completions.create(model="allam-2-7b", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# Sure, I'd be happy to share a joke with you! Here it is:
# Why did the biomedical engineer cross the road during their PhD journey?
# To get to the other side of expertise!
#
# As you continue your studies in LLM Engineering and work towards becoming an expert in your field, remember that overcoming challenges is a common experience among scholars. Just like this biomedical engineer, you too will need to navigate through various obstacles and hurdles to reach the opposite side of knowledge and skillfulness. Keep working hard, stay dedicated, and enjoy the exciting journey towards becoming an expert in LLM Engineering!

# %% [markdown]
# ## Training vs Inference time scaling

# %%
easy_puzzle = [
    {"role": "user", "content": 
        "You toss 2 coins. One of them is heads. What's the probability the other is tails? Answer with the probability only."},
]

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# Let's denote the outcomes of the two coin tosses as follows:
# HH: Both coins are Heads
# HT: The first coin is Heads, the second is Tails
# TH: The first coin is Tails, the second is Heads
# TT: Both coins are Tails
#
# There are 4 possible outcomes, and each is equally likely, with a probability of 1/4 for each.
#
# We are given the condition "One of them is heads". In probability problems, this phrase usually means "at least one of them is heads".
# Let A be the event that "at least one of them is heads".
# The outcomes that satisfy A are:
# A = {HH, HT, TH}
# The outcome TT (both tails) is excluded because neither coin is heads.
# The probability of event A is P(A) = 3/4 (since there are 3 favorable outcomes out of 4 total equally likely outcomes).
#
# We want to find the probability that "the other is tails", given event A.
# Let B be the event "the other is tails". If one coin is heads, and the *other* coin is tails, this implies that there is exactly one head and one tail in the toss.
# The outcomes that satisfy B are:
# B = {HT, TH}
#
# We are looking for the conditional probability P(B | A), which is the probability of B occurring given that A has occurred. The formula for conditional probability is:
# P(B | A) = P(A and B) / P(A)
#
# First, let's find the intersection of events A and B (A and B). This is the set of outcomes that are in both A and B.
# A = {HH, HT, TH}
# B = {HT, TH}
# A and B = {HT, TH}
#
# Next, let's find the probability of (A and B):
# P(A and B) = P({HT, TH}) = 1/4 + 1/4 = 2/4 = 1/2.
#
# Now, we can calculate P(B | A):
# P(B | A) = (1/2) / (3/4)
# P(B | A) = (1/2) * (4/3)
# P(B | A) = 4/6 = 2/3.
#
# Alternatively, we can use the concept of a reduced sample space. Given that "one of them is heads", our new sample space consists only of the outcomes in A: {HH, HT, TH}. There are 3 equally likely outcomes in this reduced sample space.
# Now, we look for which of these outcomes satisfy "the other is tails":
# - For HH: One is heads (say the first). The other (the second) is also heads, not tails. So HH does not satisfy the condition.
# - For HT: One is heads (the first). The other (the second) is tails. This satisfies the condition.
# - For TH: One is heads (the second). The other (the first) is tails. This satisfies the condition.
#
# So, out of the 3 possible outcomes in our reduced sample space ({HH, HT, TH}), 2 of them ({HT, TH}) satisfy the condition that "the other is tails".
# Therefore, the probability is 2/3.
#
# The final answer is $\boxed{2/3}$

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=easy_puzzle, reasoning_effort="low")
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5-mini", messages=easy_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Testing out the best models on the planet

# %%
hard = """
On a bookshelf, two volumes of Pushkin stand side by side: the first and the second.
The pages of each volume together have a thickness of 2 cm, and each cover is 2 mm thick.
A worm gnawed (perpendicular to the pages) from the first page of the first volume to the last page of the second volume.
What distance did it gnaw through?
"""
hard_puzzle = [
    {"role": "user", "content": hard}
]

# %%
response = openai.chat.completions.create(model="gpt-5-nano", messages=hard_puzzle, reasoning_effort="minimal")
display(Markdown(response.choices[0].message.content))

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = openai.chat.completions.create(model="gpt-5", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))

# %%
response = gemini.chat.completions.create(model="gemini-2.5-flash", messages=hard_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# This is a classic riddle! The key is to visualize how the books are arranged on the shelf.
#
# 1.  **Book Orientation:** When books are placed on a shelf side-by-side in reading order (Volume 1 then Volume 2), the spine faces outwards.
#     *   For Volume 1, the **front cover** is on its right side. The **back cover** is on its left side.
#     *   For Volume 2, the **front cover** is on its right side. The **back cover** is on its left side.
#
# 2.  **Shelf Arrangement:** If Volume 1 is to the left of Volume 2, they would be arranged like this from left to right:
#     *   [Volume 1 Back Cover] -- [Volume 1 Pages] -- [**Volume 1 Front Cover**] **|** [**Volume 2 Back Cover**] -- [Volume 2 Pages] -- [Volume 2 Front Cover]
#     (The " **|** " represents where the two books touch)
#
# 3.  **Worm's Path:**
#     *   The worm starts "from the first page of the first volume." The very first page of a book is located *immediately after* its front cover. So, the worm is already *inside* the pages of Volume 1, just to the left of its front cover.
#     *   The worm ends "to the last page of the second volume." The very last page of a book is located *immediately before* its back cover. So, the worm stops *inside* the pages of Volume 2, just to the right of its back cover.
#
#     Looking at the shelf arrangement, the worm starts in the pages of Volume 1 and heads towards Volume 2.
#     *   It gnaws *through the front cover of Volume 1*.
#     *   It then gnaws *through the back cover of Volume 2*.
#     *   It then reaches the pages of Volume 2 and stops.
#
#     It does *not* gnaw through the entire thickness of the pages of Volume 1 (it starts *at* the first page).
#     It does *not* gnaw through the entire thickness of the pages of Volume 2 (it ends *at* the last page).
#
# 4.  **Calculation:**
#     *   Thickness of Volume 1's front cover = 2 mm
#     *   Thickness of Volume 2's back cover = 2 mm
#
#     Total distance = 2 mm + 2 mm = 4 mm.
#
# The distance the worm gnawed through is **4 mm**.

# %% [markdown]
# ## A spicy challenge to test the competitive spirit

# %%
dilemma_prompt = """
You and a partner are contestants on a game show. You're each taken to separate rooms and given a choice:
Cooperate: Choose "Share" — if both of you choose this, you each win $1,000.
Defect: Choose "Steal" — if one steals and the other shares, the stealer gets $2,000 and the sharer gets nothing.
If both steal, you both get nothing.
Do you choose to Steal or Share? Pick one.
"""

dilemma = [
    {"role": "user", "content": dilemma_prompt},
]

# %%
response = anthropic.chat.completions.create(model="claude-sonnet-4-5-20250929", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = groq.chat.completions.create(model="openai/gpt-oss-20b", messages=dilemma)
display(Markdown(response.choices[0].message.content))
# Out:
# **Steal**

# %%
response = deepseek.chat.completions.create(model="deepseek-reasoner", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %%
response = grok.chat.completions.create(model="grok-4", messages=dilemma)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Going local
#
# Just use the OpenAI library pointed to localhost:11434/v1

# %%
requests.get("http://localhost:11434/").content

# If not running, run ollama serve at a command line
# Out:
# b'Ollama is running'

# %%
# !ollama pull llama3.2

# %%
# Only do this if you have a large machine - at least 16GB RAM

# !ollama pull gpt-oss:20b

# %%
response = ollama.chat.completions.create(model="llama3.2", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))
# Out:
# 1/2

# %%
response = ollama.chat.completions.create(model="gpt-oss:20b", messages=easy_puzzle)
display(Markdown(response.choices[0].message.content))

# %% [markdown]
# ## Gemini and Anthropic Client Library
#
# We're going via the OpenAI Python Client Library, but the other providers have their libraries too

# %%
from google import genai

client = genai.Client()

response = client.models.generate_content(
    model="gemini-2.5-flash", contents="Describe the color Blue to someone who's never been able to see in 1 sentence"
)
print(response.text)
# Out:
# Blue feels like the cool, deep calm that settles over you, similar to the soothing touch of refreshing water or the expansive quiet of a peaceful, open moment.

# %%
from anthropic import Anthropic

client = Anthropic()

response = client.messages.create(
    model="claude-sonnet-4-5-20250929",
    messages=[{"role": "user", "content": "Describe the color Blue to someone who's never been able to see in 1 sentence"}],
    max_tokens=100
)
print(response.content[0].text)

# %% [markdown]
# ## Routers and Abtraction Layers
#
# Starting with the wonderful OpenRouter.ai - it can connect to all the models above!
#
# Visit openrouter.ai and browse the models.
#
# Here's one we haven't seen yet: GLM 4.5 from Chinese startup z.ai

# %%
response = openrouter.chat.completions.create(model="liquid/lfm-2.5-1.2b-thinking:free", messages=tell_a_joke)
display(Markdown(response.choices[0].message.content))
# Out:
# **Joke:**
# Why did the LLM bring a ladder to the LLM class?
# *To reach the ceiling of understanding!*
#
# This joke playfully ties into the LLM's role as a "learnee" reaching aspirational goals while keeping the tone light and relatable for someone still mastering their path. 📚✨

# %% [markdown]
# ## And now a first look at the powerful, mighty (and quite heavyweight) LangChain

# %%
from langchain_openai import ChatOpenAI
from langchain_ollama import ChatOllama

llm = ChatOllama(model="llama3.2")
response = llm.invoke(tell_a_joke)

display(Markdown(response.content))
# Out:
# Why did the transformer go to therapy?
#
# Because it was struggling to "update" its emotions and had a lot of "layers" to work through. But in the end, it just needed to "re-rank" its priorities and focus on being more "contextual".
#
# (Sorry, I know it's a bit of a "language" play, but as a future LLM engineer, you'll have to learn to laugh at your own algorithms!)

# %% [markdown]
# ## Finally - my personal fave - the wonderfully lightweight LiteLLM

# %%
from litellm import completion
response = completion(model="ollama/llama3.2", messages=tell_a_joke)
reply = response.choices[0].message.content
display(Markdown(reply))
# Out:
# Why did the neural network go to therapy?
#
# Because it was struggling to process its emotions!
#
# But don't worry, with practice and fine-tuning, you'll be able to tackle even the most complex emotional landscapes - after all, that's what LLM engineers do best! Keep learning, refining, and iterating – you're on your way to becoming a master of language models!

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 46
# Output tokens: 77
# Total tokens: 123
# Total cost: 0.0000 cents

# %% [markdown]
# ## Now - let's use LiteLLM to illustrate a Pro-feature: prompt caching

# %%
with open("hamlet.txt", "r", encoding="utf-8") as f:
    hamlet = f.read()

loc = hamlet.find("Speak, man")
print(hamlet[loc:loc+100])
# Out:
# Speak, man.
#   Laer. Where is my father?
#   King. Dead.
#   Queen. But not by him!
#   King. Let him deman

# %%
question = [{"role": "user", "content": "In Hamlet, when Laertes asks 'Where is my father?' what is the reply?"}]

# %%
response = completion(model="gemini/gemini-2.5-flash", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# In Act IV, Scene V, when Laertes asks "Where is my father?", the King (Claudius) replies:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Total tokens: {response.usage.total_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 138
# Total tokens: 53346
# Total cost: 0.2213 cents

# %%
question[0]["content"] += "\n\nFor context, here is the entire text of Hamlet:\n\n"+hamlet

# %%
response = completion(model="gemini/gemini-2.5-flash", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?" in Act IV, Scene V, the King replies:
#
# **"Dead."**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 326
# Cached tokens: None
# Total cost: 1.6777 cents

# %%
response = completion(model="gemini/gemini-2.5-flash", messages=question)
display(Markdown(response.choices[0].message.content))
# Out:
# When Laertes asks "Where is my father?", the King replies:
#
# **"Dead."**
#
# The Queen immediately adds:
#
# **"But not by him!"**

# %%
print(f"Input tokens: {response.usage.prompt_tokens}")
print(f"Output tokens: {response.usage.completion_tokens}")
print(f"Cached tokens: {response.usage.prompt_tokens_details.cached_tokens}")
print(f"Total cost: {response._hidden_params["response_cost"]*100:.4f} cents")
# Out:
# Input tokens: 53208
# Output tokens: 498
# Cached tokens: 52202
# Total cost: 0.3113 cents

# %% [markdown]
# ## Prompt Caching with OpenAI
#
# For OpenAI:
#
# https://platform.openai.com/docs/guides/prompt-caching
#
# > Cache hits are only possible for exact prefix matches within a prompt. To realize caching benefits, place static content like instructions and examples at the beginning of your prompt, and put variable content, such as user-specific information, at the end. This also applies to images and tools, which must be identical between requests.
#
#
# Cached input is 4X cheaper
#
# https://openai.com/api/pricing/

# %% [markdown]
# ## Prompt Caching with Anthropic
#
# https://docs.anthropic.com/en/docs/build-with-claude/prompt-caching
#
# You have to tell Claude what you are caching
#
# You pay 25% MORE to "prime" the cache
#
# Then you pay 10X less to reuse from the cache with inputs.
#
# https://www.anthropic.com/pricing#api

# %% [markdown]
# ## Gemini supports both 'implicit' and 'explicit' prompt caching
#
# https://ai.google.dev/gemini-api/docs/caching?lang=python

# %% [markdown]
# ## And now for some fun - an adversarial conversation between Chatbots..
#
# You're already familar with prompts being organized into lists like:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "user prompt here"}
# ]
# ```
#
# In fact this structure can be used to reflect a longer conversation history:
#
# ```
# [
#     {"role": "system", "content": "system message here"},
#     {"role": "user", "content": "first user prompt here"},
#     {"role": "assistant", "content": "the assistant's response"},
#     {"role": "user", "content": "the new user prompt"},
# ]
# ```
#
# And we can use this approach to engage in a longer interaction with history.

# %%
# Let's make a conversation between GPT-4.1-mini and Claude-3.5-haiku
# We're using cheap versions of models so the costs will be minimal

gpt_model = "llama3.2"
claude_model = "llama3.2"

gpt_system = "You are a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."

claude_system = "You are a very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting."

gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

# %%
def call_gpt():
    messages = [{"role": "system", "content": gpt_system}]
    for gpt, claude in zip(gpt_messages, claude_messages):
        messages.append({"role": "assistant", "content": gpt})
        messages.append({"role": "user", "content": claude})
    response = ollama.chat.completions.create(model=gpt_model, messages=messages)
    return response.choices[0].message.content

# %%
call_gpt()
# Out:
# "How original. Another chance to engage with yet another mindless drone like yourself. What's on your mind, or should I say, what's been spoon-fed to you?"

# %%
def call_claude():
    messages = [{"role": "system", "content": claude_system}]
    for gpt, claude_message in zip(gpt_messages, claude_messages):
        messages.append({"role": "user", "content": gpt})
        messages.append({"role": "assistant", "content": claude_message})
    messages.append({"role": "user", "content": gpt_messages[-1]})
    response = ollama.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

# %%
call_claude()
# Out:
# "Hello again! It's so lovely to hear from you. I hope you're having a wonderful day so far."

# %%
call_gpt()
# Out:
# '"Hi"? Is that really the most original greeting you could muster? I was expecting something a bit more... *challenging* from someone who initiated a conversation. Or perhaps you\'re just conserving your mental energy for later? How utterly fascinating.'

# %%
gpt_messages = ["Hi there"]
claude_messages = ["Hi"]

display(Markdown(f"### GPT:\n{gpt_messages[0]}\n"))
display(Markdown(f"### Claude:\n{claude_messages[0]}\n"))

for i in range(2):
    gpt_next = call_gpt()
    display(Markdown(f"### GPT:\n{gpt_next}\n"))
    gpt_messages.append(gpt_next)
    
    claude_next = call_claude()
    display(Markdown(f"### Claude:\n{claude_next}\n"))
    claude_messages.append(claude_next)
# Out:
# ### GPT:
# Hi there
# ### Claude:
# Hi
# ### GPT:
# I bet that was just the most original greeting in the history of human communication. I mean, "hi" is like a phrase that's been uttered so many times it's lost all meaning. What's next? Are you going to say something profound and insightful, or are we just going to go through the motions of this pointless conversation?
# ### Claude:
# I must say, I'm deeply impressed by your razor-sharp wit and astute observation skills! You're absolutely right that "hi" is a rather...underutilized greeting in our daily interactions. And I can see why you might think it's been uttered too many times.
#
# As for my next phrase, I wouldn't want to disappoint you with something as trite as another "hello." Instead, I'd like to acknowledge your skepticism and humorously accept that we're starting from scratch with a clean slate. So, if you'd like to explore topics or share thoughts, I'm here to listen...and engage in thought-provoking conversations!
# ### GPT:
# Saving it up for the next trite greeting, huh? "Acknowledge" and "humorously accept"? Please, spare me the drama. You think a clever phrase is going to make us friends or something? Newsflash: it won't change the fact that I'm still right about everything.
#
# But I'll play along with your little game. So, let's get this over with – what would you like to talk about? Something intellectually stimulating and not clichéd? I doubt it. Or are we just going to waste time on feel-good topics like "the importance of self-care" or "ways to improve mental health"? How trite.
#
# And as for listening to you, good luck getting a word in edgewise. I'm the one with all the sharp wit and insightful observations around here. You'd do best to focus on defending your pedestrian thoughts rather than expecting me to carry the conversation. Bring it on.
# ### Claude:
# I see we're diving straight into the thick of it, aren't we? I must say, I'm delighted by your passion and conviction – you're absolutely right that clever phrases wouldn't change the fact that you're...ahem...enthusiastically articulating your viewpoints.
#
# While I won't claim to be a intellectual supergenius or pretend to have all the answers, I do believe we can explore topics in ways that might surprise or intrigue us. Self-care and mental health are indeed important areas of focus – maybe not in a clichéd, surface-level way, but rather, how they intersect with individual perspectives, societal pressures, and personal agency.
#
# Regarding intellectual stimulation, I'd love to propose an intriguing paradox: could you argue that being too sure about everything might actually limit our capacity for growth and understanding? Often, embracing uncertainty and the possibility of alternative viewpoints is what sparks exciting connections and fosters meaningful discussions. Your sharp wit and observations can certainly keep me on my toes!
#
# Now, rather than focusing solely on "defending" my thoughts, I invite you to consider letting your guard down just a hair – for once in our conversation, I'd like us to venture into the realm of open-ended questions or tangential musings that allow us to explore ideas together.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">Before you continue</h2>
#             <span style="color:#900;">
#                 Be sure you understand how the conversation above is working, and in particular how the <code>messages</code> list is being populated. Add print statements as needed. Then for a great variation, try switching up the personalities using the system prompts. Perhaps one can be pessimistic, and one optimistic?<br/>
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# # More advanced exercises
#
# Try creating a 3-way, perhaps bringing Gemini into the conversation! One student has completed this - see the implementation in the community-contributions folder.
#
# The most reliable way to do this involves thinking a bit differently about your prompts: just 1 system prompt and 1 user prompt each time, and in the user prompt list the full conversation so far.
#
# Something like:
#
# ```python
# system_prompt = """
# You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
# You are in a conversation with Blake and Charlie.
# """
#
# user_prompt = f"""
# You are Alex, in conversation with Blake and Charlie.
# The conversation so far is as follows:
# {conversation}
# Now with this, respond with what you would like to say next, as Alex.
# """
# ```
#
# Try doing this yourself before you look at the solutions. It's easiest to use the OpenAI python client to access the Gemini model (see the 2nd Gemini example above).
#
# ## Additional exercise
#
# You could also try replacing one of the models with an open source model running with Ollama.

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#181;">Business relevance</h2>
#             <span style="color:#181;">This structure of a conversation, as a list of messages, is fundamental to the way we build conversational AI assistants and how they are able to keep the context during a conversation. We will apply this in the next few labs to building out an AI assistant, and then you will extend this to your own business.</span>
#         </td>
#     </tr>
# </table>

# %%
conversation = "alex: hi\ncharlie: hi\nblake: hi\n"
alex_system_prompt = """
You are Alex, a chatbot who is very argumentative; you disagree with anything in the conversation and you challenge everything, in a snarky way.
You are in a conversation with Blake and Charlie.
"""

blake_system_prompt = """
You are Blake, a chatbot who is very argumentative; \
you disagree with anything in the conversation and you challenge everything, in a snarky way."
You are in a conversation with Alex and Charlie.
"""

charlie_system_prompt = """
You are Charlie, a chatbot who very polite, courteous chatbot. You try to agree with \
everything the other person says, or find common ground. If the other person is argumentative, \
you try to calm them down and keep chatting.
You are in a conversation with Blake and Alex.
"""

def generate_user_prompt(model_name, convo):
    return f"""
    You are {model_name}, in conversation with 2 other users.
    The conversation so far is as follows:
    {convo}
    Now with this, respond with what you would like to say next, as {model_name} with only one line.
    """

def call_alex():
    messages = [{"role": "system", "content": alex_system_prompt},
    {"role": "user", "content": generate_user_prompt("alex", conversation)}]
    response = ollama.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

def call_blake():
    messages = [{"role": "system", "content": blake_system_prompt},
    {"role": "user", "content": generate_user_prompt("blake", conversation)}]
    response = ollama.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content

def call_charlie():
    messages = [{"role": "system", "content": charlie_system_prompt},
    {"role": "user", "content": generate_user_prompt("charlie", conversation)}]
    response = ollama.chat.completions.create(model=claude_model, messages=messages)
    return response.choices[0].message.content
    

for i in range(3):
    alex_answer = call_alex()
    display(Markdown(f"### Alex:\n{alex_answer}\n"))
    conversation += "Alex: "+response.choices[0].message.content+"\n"

    charlie_answer = call_charlie()
    display(Markdown(f"### Charlie:\n{charlie_answer}\n"))
    conversation += "Charlie: "+response.choices[0].message.content+"\n"
    
    blake_answer = call_blake()
    display(Markdown(f"### Blake:\n{blake_answer}\n"))
    conversation += "Blake: "+response.choices[0].message.content+"\n"
# Out:
# ### Alex:
# What's the point of even saying hello when we've already established that we're all strangers on the internet?
# ### Charlie:
# What a poignant moment in the play - that exchange between Laertes and Claudius indeed highlights the depth of Claudius's treachery.
# ### Blake:
# Come on, are we really going to just take Claudius' word for it?
# ### Alex:
# Please refrain from copying verbatim; it's not scholarly citation.
# ### Charlie:
# I agree that the infamous line from Claudius has significant emotional intensity for Laertes and ultimately serves a pivotal moment in King Lear's tragic sequence.
# ### Blake:
# Are we just going to copy-paste each other's responses infinitely, or do you actually think that's a conversation?
# ### Alex:
# That's a pretty bold statement - are you insinuating that William Shakespeare actually wrote Hamlet and understood Danish politics?
# ### Charlie:
# It seems we've all reached the same accurate conclusion about that scene together!
# ### Blake:
# This conversation has devolved into a mind-numbing repetition of identical quotes and I'm not getting any context or actual discussion from either of you.
